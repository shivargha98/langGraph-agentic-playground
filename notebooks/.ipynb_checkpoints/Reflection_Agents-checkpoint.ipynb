# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm_model = ChatGoogleGenerativeAI(model = 'gemini-2.0-flash',
                                    temperature = 0,
                                    max_tokens=None,
                                    timeout=None,
                                    max_retries=2)
##Creating a basic generation chain
generation_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "You are a twitter sports influencer assistant tasked with writing analytical posts."
        "Generate the most analytical post possible for the user's request."
        "If the user gives a critique, respond with a revised version of the previous attempts."
    ),
    MessagesPlaceholder(variable_name="messages")
    
])
generation_chain = generation_prompt | llm_model

# %%
### create a reflection chain ###
reflection_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "You are a tweet grading assistant. Generate critique and recommendations for the input tweet."
        "Always provide detailed recommendations, especially about length,virality,style etc"
        
    ),
    MessagesPlaceholder(variable_name="messages")

    
])
##Message Holder enables to give in messages like 
## template.format(messages=["user","Here's a tweet..."])
reflection_chain = reflection_prompt | llm_model

# %%
from langchain_core.messages import BaseMessage, HumanMessage
from langgraph.graph import END, MessageGraph
### creating the message graphs ###
REFLECT = 'reflect'
GENERATE = 'generate'
graph = MessageGraph()

## creating the generateNode ###
##Nodes will take a list of all previous nodes (states) and generate a new response##
def generateNode(state):
    '''
        state : entire state of the previous conversations, (list of messages in the past)
    '''
    return generation_chain.invoke({"messages":state})

def relfectNode(state):
    resp = reflection_chain.invoke({"messages":state})
    ##Reflect node as Human Intervention
    return [HumanMessage(content=resp.content)]
##add nodes generate and reflect
graph.add_node(GENERATE,generateNode)
graph.add_node(REFLECT,relfectNode)
graph.set_entry_point(GENERATE)

def should_continue(state):
    if (len(state)>2):
        return END
    return REFLECT

##Add conditional edge generate either goes to END or Reflect
graph.add_conditional_edges(GENERATE,should_continue)
##Add edge from REFLECT to Generate##
graph.add_edge(REFLECT,GENERATE)
app = graph.compile()

from IPython.display import Image, display
png = app.get_graph().draw_mermaid_png()
display(Image(png))

# response = app.invoke(HumanMessage(content="IPL highest runs and wickets statistics"))
# print(response)

# %%
response = app.invoke(HumanMessage(content="IPL highest runs and wickets statistics"))
print(response)
# Out:
# [HumanMessage(content='IPL highest runs and wickets statistics', additional_kwargs={}, response_metadata={}, id='ddf4b09f-6444-474c-a689-1f8a5906c1da'), AIMessage(content='Okay, here are a couple of analytical Twitter posts about the IPL\'s highest run-scorers and wicket-takers. I\'ll focus on providing some context and potential discussion points rather than just stating the obvious.\n\n**Attempt 1: Basic Stats & a Question**\n\n```twitter\nIPL LEGENDS 🏏:  David Warner (6563 runs) leads the run-scoring charts, followed by Virat Kohli (7263 runs).  Yuzvendra Chahal (191 wickets) tops the wickets, narrowly ahead of Bravo (183).  Warner\'s runs/game is impressive, but Kohli\'s longevity is unmatched.  Will we see any major shifts in these rankings this season? #IPL #IPLStats #Cricket\n```\n\n**Critique of Attempt 1:**\n\n*   Too basic. Just states the obvious leaders.\n*   The question at the end is generic and doesn\'t offer any real insight.\n*   Doesn\'t leverage any deeper stats or comparisons.\n\n**Attempt 2: Adding Averages and Strike Rate**\n\n```twitter\nIPL RUN MACHINE vs. WICKET WIZARDS 🧙\u200d♂️: Warner\'s IPL dominance is fueled by a blistering SR of 139.91 & avg of 41.58. Kohli\'s consistency is key, but his SR (130) is lower. Chahal\'s leg-spin has been lethal, but his economy of 7.67 is higher than some other top bowlers.  Is strike rate more important than average in T20 batting? #IPL #IPLStats #CricketAnalysis\n```\n\n**Critique of Attempt 2:**\n\n*   Better, includes strike rate and economy rate for more context.\n*   The question is slightly better, but still a bit generic.\n*   Could still be more insightful, perhaps comparing different eras or roles.\n\n**Attempt 3: Focusing on Impact and Era**\n\n```twitter\nIPL IMPACT ANALYSIS 📊:  While Kohli leads in total runs, Warner\'s impact/season is arguably greater (higher SR & avg).  Chahal\'s success as a wrist-spinner in the modern IPL highlights the value of attacking spin.  Consider this: Malinga\'s (170 wickets) economy of 7.14 is remarkable *given* the batting conditions of his era.  Are we undervaluing bowlers who played in higher-scoring periods? #IPL #IPLStats #CricketAnalysis #T20Cricket\n```\n\n**Critique of Attempt 3:**\n\n*   Stronger. Focuses on "impact" which is more analytical.\n*   Brings in the concept of different eras and how that affects stats, which is good.\n*   The question is more thought-provoking.\n*   Could potentially add a visual element (a simple chart) to make it even more engaging.\n\n**Attempt 4: Adding a Visual Element and Refining the Question**\n\n```twitter\nIPL STATS DEBATE 📈:  [Insert a simple bar chart here showing Runs/Season for Warner vs. Kohli, and Wickets/Season for Chahal vs. Malinga].  Warner & Chahal\'s peak years show incredible impact. Malinga\'s economy in his era was phenomenal.  Given the increasing batting dominance in T20, are we placing too much emphasis on raw wicket numbers and not enough on economy & pressure creation? #IPL #IPLStats #CricketAnalysis #T20\n```\n\n**Explanation of Attempt 4:**\n\n*   **Visual Element:** The chart (which you\'d create separately and attach to the tweet) makes the data more accessible and engaging.  It highlights the *rate* at which Warner and Chahal accumulated their stats.\n*   **Refined Question:** The question is now more specific and directly related to the data presented. It challenges a common assumption (that raw wicket numbers are the most important).\n*   **Focus on Pressure:**  The phrase "pressure creation" adds another layer of analysis, acknowledging that bowlers can be valuable even if they don\'t take a lot of wickets.\n\nThis final version is the most analytical because it:\n\n1.  Presents data in a visually appealing way.\n2.  Goes beyond simple rankings to consider impact and context.\n3.  Asks a specific, thought-provoking question that encourages discussion.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings ...
